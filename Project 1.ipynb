# %%
file_names = ["IT Salary Survey EU 2018.csv","T Salary Survey EU 2019.csv", "IT Salary Survey EU  2020.csv"]

# %%
title_column = []
data = open(file_names[0], 'r', encoding='utf-8')
data = data.readline()
data = data.split(',')
print(data)
# Out:
# ['Timestamp', 'Age', 'Gender', 'City', 'Position', 'Years of experience', 'Your level', 'Current Salary', 'Salary one year ago', 'Salary two years ago', 'Are you getting any Stock Options?', 'Main language at work', 'Company size', 'Company type\n']

# %%
import glob
import os
path = r"C:\Users\HP\hello world"
all_files = glob.glob(os.path.join(path, '/*.csv'))
li = []

for file in file_names:
    df = pd.read_csv(file, index_col=None, header = 0)
    li.append(df)
    
frame = pd.concat(li, axis =0, ignore_index=True)
frame.head()
# Out:
#              Timestamp   Age Gender     City                       Position  \
# 0  14/12/2018 12:41:33  43.0      M  München                   QA Ingenieur
# 1  14/12/2018 12:42:09  33.0      F  München  Senior PHP Magento developer
# 2  14/12/2018 12:47:36  32.0      M  München              Software Engineer
# 3  14/12/2018 12:50:15  25.0      M  München      Senior Frontend Developer
# 4  14/12/2018 12:50:31  39.0      M  München                    UX Designer
#
#    Years of experience Your level  Current Salary  Salary one year ago  \
# 0                 11.0     Senior         77000.0              76200.0
# 1                  8.0     Senior         65000.0              55000.0
# 2                 10.0     Senior         88000.0              73000.0
# 3                  6.0     Senior         78000.0              55000.0
# 4                 10.0     Senior         69000.0              60000.0
#
#    Salary two years ago  ... Years of experience in Germany  \
# ...

# %%
array =[]
for name in file_names:
    with open(name,'r',encoding = 'utf-8') as f:
        title = f.readline()
        array.append(title.split(','))
        
        for line in f:
            if title == line:
                continue
            else:
                array.append(line.split(','))

# %%
print("{}, {}".format(array[0][3], array[2][3]))
# Out:
# City, München

# %%
''' basic information'''
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %%
'''data description'''
df.describe()
# Out:
#                Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  1226.000000                                       1.253000e+03
# mean     32.509788                                       8.027904e+07
# std       5.663804                                       2.825061e+09
# min      20.000000                                       1.000100e+04
# 25%      29.000000                                       5.880000e+04
# 50%      32.000000                                       7.000000e+04
# 75%      35.000000                                       8.000000e+04
# max      69.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                       8.850000e+02
# mean                                        6.322459e+05
# std                                         1.680508e+07
# ...

# %%
df.shape
# Out:
# (1253, 23)

# %%
'''find duplicates'''
df.duplicated().sum()
# Out:
# 0

# %%
'''find unique values'''
'''find unique values'''
df['Age'].unique()
df['Gender'].unique()
df['City'].unique()
# Out:
# array(['Munich', 'Berlin', 'Hamburg', 'Wolfsburg', 'Stuttgart',
#        'Schleswig-Holstein', 'London', 'Konstanz area', 'Frankfurt',
#        'Cologne', 'Kempten', 'Münster', 'Erlangen', 'Vienna', 'Moldova',
#        'Rosenheim', 'Mannheim ', 'Boeblingen', 'Düsseldorf', 'Ingolstadt',
#        'Nürnberg', 'Ansbach', 'Leipzig', 'Mannheim', 'Tuttlingen', 'Bonn',
#        'Moscow', 'Koblenz', 'Warsaw', 'Heidelberg', 'Karlsruhe', 'Köln',
#        'Aachen', 'Karlsruhe ', 'Samara', 'Riga, Latvia', 'Dusseldorf',
#        'Zurich', 'Helsinki', 'Würzburg', 'Kiev', 'Den Haag', 'Amsterdam',
#        'Cracovia', 'Tallinn', 'Prague', 'Utrecht', 'Stockholm',
#        'Braunschweig ', 'Dresden', 'Kyiv', 'Stuttgart ', 'Malta',
#        'Lübeck', 'Nuremberg ', 'Bodensee', 'Milan', 'Salzburg', 'Rome',
#        'Wroclaw', 'Cupertino', 'Paris', 'Dublin ', 'Paderborn',
#        'Konstanz', 'Ulm', 'Düsseldorf ', 'Barcelona', 'Bölingen',
# ...

# %%
'''Find null values'''
df.isnull().sum()
# Out:
# Timestamp                                                                                                                    0
# Age                                                                                                                         27
# Gender                                                                                                                      10
# City                                                                                                                         0
# Position                                                                                                                     6
# Total years of experience                                                                                                   16
# Years of experience in Germany                                                                                              32
# ...

# %%
'''replace null values'''
df.replace(np.nan,'0',inplace = True)
df.isnull().sum()
# Out:
# Timestamp                                                                                                                  0
# Age                                                                                                                        0
# Gender                                                                                                                     0
# City                                                                                                                       0
# Position                                                                                                                   0
# Total years of experience                                                                                                  0
# Years of experience in Germany                                                                                             0
# ...

# %%
'''Knowing the data types'''
df.dtypes
# Out:
# Timestamp                                                                                                                   object
# Age                                                                                                                         object
# Gender                                                                                                                      object
# City                                                                                                                        object
# Position                                                                                                                    object
# Total years of experience                                                                                                   object
# Years of experience in Germany                                                                                              object
# ...

# %%
'''filtering data'''
df[df['Age']==30.0].head()
# Out:
#               Timestamp   Age Gender    City          Position   \
# 37  24/11/2020 11:29:18  30.0   Male  Berlin  Software Engineer
# 44  24/11/2020 11:30:45  30.0   Male  Berlin  Software Engineer
# 75  24/11/2020 11:43:28  30.0   Male  Berlin  Backend Developer
# 76  24/11/2020 11:43:34  30.0   Male  Munich             DevOps
# 82  24/11/2020 11:44:34  30.0   Male  Berlin  Software Engineer
#
#    Total years of experience Years of experience in Germany Seniority level  \
# 37                         8                              3          Senior
# 44                         6                              3          Senior
# 75                         5                              5          Middle
# 76                         8                              2          Middle
# 82                        10                              2          Senior
#
#    Your main technology / programming language  \
# 37                                  JavaScript
# ...

# %%
df.corr()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14596\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                                     Yearly brutto salary (without bonus and stocks) in EUR
# Yearly brutto salary (without bonus and stocks)...                                                1.0
